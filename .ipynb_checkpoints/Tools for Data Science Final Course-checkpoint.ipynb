# %% [markdown]
# # Final Course Graded Assignment

# %% [markdown]
# # Introduction

# %% [markdown]
# Hi everyone! I am Alfi and this is my notebook for the final assignment of the Tools for Data Science course. I am a data scientist from Indonesia. Nice to meet you!

# %% [markdown]
# ## Data Science Languages
# As far as I know, we have a lot of options to learn data science languages. Some that commonly used are:
# * Python: easy to understand syntax, open source, able to perform visualizations and data manipulation
# * R: same with python
# * SQL: the difference is that the visualizations are not able to be produced from this language
# * Matlab
# * Java
# * Scala
# * Julia
# * C++

# %% [markdown]
# ## Data Science Libraries
# Well, we can see that the languages can't stand alone, it still needs the libraries to support the enabling the advancement of the data science steps. From the 2 commonly used language I know, these are the libraries that could be useful for data science:
# * Python: TensorFlow, Matplotlib, pandas, numpy
# * R: caret, ggplot, dplyr

# %% [markdown]
# ## Data Science Tools
# This is the tools that could be useful for data scientists:
#
# No|Name|Category
# ---|----|---|
# 1|Tableau|Data visualization
# 2| Google Data Studio|Data visualization
# 3| Power BI| Data visualization
# 4| MySQL|Data storage and manipulation
# 5| Jupyter Notebook|IDE for python
# 6| RStudio| IDE for R
# 7| Github|Version control

# %% [markdown]
# ## Arithmetic Example
# As I said before, Jupyter Notebook is an IDE for Python language so the user can write the code or even the text. Here is the example of arithmetic operation to count `(33 * 50) + 74 = 1724`

# %%
(33 * 50) +  74
# Out:
# 1724

# %% [markdown]
# More than that, we also can convert hours into minutes using arithmetic solution. In reality, every 1 hours counts as 60 minutes, so we can use the multiplication of X hours to know the Y minutes.

# %%
## Example: we want to know how many minutes for 1.5 hours
h = 1.5
m = 1.5*60
print('For {} hours counts as {} minutes'.format(h, m))
# Out:
# For 1.5 hours counts as 90.0 minutes

# %% [markdown]
# <b> Objectives </b> <br>
# Through this notebook, these are the objectives for the readers & myself:
# 1. Understand more about the use of Jupyter Notebook
# 2. Succeeded to implement Data Science languages & libraries in real world application
# 3. Dont forget to always practice

# %% [markdown]
# ## Thank you!
# Author's name: Jihan Alfiyyah Munajat <br>
# Connect my [Linkedin](https://www.linkedin.com/in/jihanalfi/)

# %% [markdown]
# ![image.png](attachment:9cba5871-bcc0-4a78-9534-f510444775ae.png)
